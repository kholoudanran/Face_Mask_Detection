# %%
# !pip install ultralytics

# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="YBaBoieNSNnA7fkaAghG")
# project = rf.workspace("yvonne-yzoqi").project("mask-edq30")
# version = project.version(1)
# dataset = version.download("yolov11")

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Train the model
train_results = model.train(
    data="",  # path to dataset YAML
    epochs=,  # number of training epochs
    imgsz=,  # training image size
    # batch=,  # batch size
    # patience=,  # early stopping patience
    # lr0=,  # initial learning rate (i.e. SGD=1E-2, Adam=1E-3)
    # optimizer="",  # optimizer (SGD, Adam, RMSProp)
    # device=0,  # device to run on, i.e. device=0 or device=0,1,2,3 or device=cpu
)

# %%
# !ls /content/runs/detect/train

# %%
from IPython.display import Image as IPyImage

IPyImage(filename=f'', width=600)

# %%
# Load a model
my_model = YOLO("")

# Perform object detection on an image
results_1 = my_model("", conf=0.5, iou=0.4, save=True)
results_1[0].show()
